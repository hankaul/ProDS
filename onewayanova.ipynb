# %% [markdown]
# 문제1. 분산 분석 시 사용하는 함수 또는 라이브러리와 관련없는 것은?

# %%
from scipy import stats
#stats.f_oneway

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %% [markdown]
# 문제 2. 계절별 기온 평균을 분산분석시 검정통계량은?

# %%
import pandas as pd
df= pd.read_csv('data2/bike.csv')

# %%
df_1 = df[df['season']==1]
df_2 = df[df['season']==2]
df_3 = df[df['season']==3]
df_4 = df[df['season']==4]

# %%
stats.f_oneway(df_1['temp'],df_2['temp'],df_3['temp'],df_4['temp'])
# Out:
# F_onewayResult(statistic=6040.687453316907, pvalue=0.0)

# %% [markdown]
# 문제 3. 요일별 registered의 평균을 사후검정 했을 떄 평균이 유의미하게 차이 나지 않은 조합은 총 몇개?

# %%
df['datetime']= pd.to_datetime(df['datetime'])

# %%
df['day'] = df['datetime'].dt.dayofweek

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
result= pairwise_tukeyhsd(endog = df['registered'], groups= df['day'])
print(result)
#t 귀무가설 : 두 그룹간의 평균은 같다. 
#reject = False -> 귀무가설 채택
#답 11
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#      0      1   6.1979    0.9  -9.7188  22.1146  False
#      0      2    5.343    0.9 -10.5427  21.2287  False
#      0      3  12.7424 0.2132  -3.1383   28.623  False
#      0      4   6.2956    0.9  -9.6471  22.2384  False
#      0      5 -27.5063  0.001 -43.3091 -11.7036   True
#      0      6 -36.7583  0.001 -52.5734 -20.9431   True
#      1      2  -0.8549    0.9 -16.7716  15.0618  False
#      1      3   6.5445 0.8863  -9.3671  22.4561  False
#      1      4   0.0977    0.9 -15.8759  16.0713  False
#      1      5 -33.7042  0.001 -49.5381 -17.8704   True
#      1      6 -42.9562  0.001 -58.8024 -27.1099   True
#      2      3   7.3994 0.7916  -8.4813    23.28  False
#      2      4   0.9526    0.9 -14.9901  16.8954  False
#      2      5 -32.8493  0.001 -48.6521 -17.0466   True
# ...

# %%
result= pairwise_tukeyhsd(df['registered'],  df['temp'])
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#   0.82   1.64   11.1429    0.9 -443.6564 465.9421  False
#   0.82   2.46  -36.0571    0.9 -368.1956 296.0813  False
#   0.82   3.28  -58.4026    0.9 -332.6569 215.8517  False
#   0.82    4.1  -27.7662    0.9 -258.5856 203.0531  False
#   0.82   4.92  -20.2071    0.9  -246.763 206.3487  False
#   0.82   5.74  -25.5394    0.9 -246.8356 195.7569  False
#   0.82   6.56  -11.7065    0.9 -231.1803 207.7674  False
#   0.82   7.38  -12.8005    0.9 -234.1609 208.5598  False
#   0.82    8.2    0.9638    0.9 -216.6827 218.6104  False
#   0.82   9.02   -7.6959    0.9  -225.095 209.7032  False
#   0.82   9.84    3.8299    0.9 -213.1018 220.7617  False
#   0.82  10.66     8.423    0.9 -208.2198 225.0658  False
#   0.82  11.48   25.2423    0.9 -193.2585 243.7432  False
#   0.82   12.3    33.187    0.9 -183.1477 249.5217  False
# ...

# %%
test = pairwise_tukeyhsd(df['registered'],  df['day'])
print(result

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  day
# ...
