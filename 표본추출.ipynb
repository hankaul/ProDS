# %% [markdown]
# ### 표본 추출
#
# - 층화 표본 추출 : 군집별로 지정한 비율 만큼의 데이터를 임의 추출
# - 계통 추출 : 첫 표본을 무작위로 추출하고 표집 간격 k 만큼 떨어진 곳의 데이터 추출
# - 군집 추출 : 소수의 군집으로 분할하고 일정 수의 소집단을 임의 표본 추출

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
bike = pd.read_csv('data2/bike.csv')

# %%
bike.groupby('season').sample(n=10)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 512    2011-02-04 12:00:00       1        0           1        2   9.84
# 229    2011-01-10 20:00:00       1        0           1        1   6.56
# 113    2011-01-05 22:00:00       1        0           1        1   7.38
# 985    2011-03-05 12:00:00       1        0           0        2  18.04
# 612    2011-02-08 16:00:00       1        0           1        1   9.02
# 1179   2011-03-13 20:00:00       1        0           0        1  13.12
# 626    2011-02-09 07:00:00       1        0           1        1   2.46
# 5577   2012-01-07 12:00:00       1        0           0        1  16.40
# 196    2011-01-09 11:00:00       1        0           0        1   6.56
# 178    2011-01-08 17:00:00       1        0           0        1   6.56
# 2625   2011-06-17 07:00:00       2        0           1        1  24.60
# 2039   2011-05-11 21:00:00       2        0           1        1  22.14
# ...

# %%
bike.groupby('season').sample(frac=0.1,weights=10)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 1022   2011-03-07 03:00:00       1        0           1        1   8.20
# 5840   2012-01-18 13:00:00       1        0           1        1  12.30
# 6714   2012-03-17 01:00:00       1        0           0        2  18.04
# 795    2011-02-16 14:00:00       1        0           1        1  18.86
# 106    2011-01-05 15:00:00       1        0           1        1  12.30
# ...                    ...     ...      ...         ...      ...    ...
# 9557   2012-10-02 14:00:00       4        0           1        3  24.60
# 4824   2011-11-14 02:00:00       4        0           1        1  18.86
# 4358   2011-10-13 15:00:00       4        0           1        1  27.06
# 10380  2012-11-17 22:00:00       4        0           0        2  13.12
# 5341   2011-12-16 15:00:00       4        0           1        2  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# 문제1. 주어진 데이터의 1.23%를 추출하면 몇개의 행이 추출되는가? (bike)

# %%
df.sample(frac=0.0123) #134개
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 4290   2011-10-10 19:00:00       4        1           0        2  23.78
# 8741   2012-08-06 14:00:00       3        0           1        1  33.62
# 4802   2011-11-13 04:00:00       4        0           0        2  14.76
# 5062   2011-12-05 00:00:00       4        0           1        1  13.12
# 750    2011-02-14 15:00:00       1        0           1        1  22.96
# ...                    ...     ...      ...         ...      ...    ...
# 3576   2011-08-18 22:00:00       3        0           1        2  28.70
# 10407  2012-11-19 01:00:00       4        0           1        2  14.76
# 934    2011-03-03 09:00:00       1        0           1        1   6.56
# 7056   2012-04-12 09:00:00       2        0           1        1  14.76
# 5822   2012-01-17 19:00:00       1        0           1        1  18.86
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# 문제2. Season 기준 5%씩 추출 시 추출되는 총 행의 수는? (bike)

# %%
df.groupby('season').sample(frac=0.05)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 731   2011-02-13 20:00:00       1        0           0        1  16.40
# 6062  2012-02-08 20:00:00       1        0           1        3   9.84
# 161   2011-01-08 00:00:00       1        0           0        2   7.38
# 5430  2012-01-01 08:00:00       1        0           0        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 4238  2011-10-08 15:00:00       4        0           0        1  27.06
# 4847  2011-11-15 01:00:00       4        0           1        1  22.96
# 4472  2011-10-18 09:00:00       4        0           1        2  21.32
# 4612  2011-11-05 06:00:00       4        0           0        1  10.66
# 4138  2011-10-04 11:00:00       4        0           1        1  22.14
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.groupby('season').sample(frac=0.05).shape[0] #답 545
# Out:
# 545

# %% [markdown]
# 3. 학습과 평가용 데이터 세트로8:2 분리시 평가용 데이터의 최고 기온은?

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df, train_size=0.8, random_state=123)

# %%
test['temp'].max() #답 39.36
# Out:
# 39.36
